# %% [markdown]
# # Dicionários
#
# ## Aula 8.3

# %% [markdown]
# ### Q1.
#
# Escreva uma função em Python chamada ```contagem_caracteres``` que recebe uma string como parâmetro e retorna um dicionário onde as chaves são os caracteres presentes na string e os valores são a contagem de cada caractere.

# %%
# Implemente aqui a função contagem_caracteres

def contagem_caracteres(texto):
    # Criamos um dicionário vazio para guardar os caracteres e suas contagens
    contador = {}

    # Percorremos cada caractere da string recebida
    for caractere in texto:
        # Se o caractere já está no dicionário, aumentamos a contagem
        if caractere in contador:
            contador[caractere] += 1
        else:
            # Se não está, adicionamos ele com o valor 1
            contador[caractere] = 1

    # Retornamos o dicionário com os resultados
    return contador

# %%
# Exemplo de uso:
frase = "python programming"
resultado = contagem_caracteres(frase)
print(resultado)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 2, ' ': 1, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 1}

# %% [markdown]
# ### Q2.
#
# Baixe o arquivo contendo o roteiro do filme brasileiro "Estômago" e salve em seu computador com o nome "estomago.txt".
#
# https://aplauso.imprensaoficial.com.br/edicoes/12.0.813.502/12.0.813.502.txt
#
# - Escreva um script python que abre o arquivo de texto e cria um dicionário contando a quantidade de vezes que cada palavra aparece no texto.
# - Em seguida ordene o dicionário de forma decrescente pelos valores. Dessa maneira ele irá apresentar as palavras mais frequentes no início.
# - Apresente na tela o dicionário ordenado

# %%
# Implemente aqui sua solução
import string
from collections import Counter

def contar_palavras(nome_arquivo):
    try:
        # Tenta abrir o arquivo com a codificação 'ISO-8859-1' (comum em textos em português)
        with open(nome_arquivo, 'r', encoding='ISO-8859-1') as arquivo:
            texto = arquivo.read()

        # Remove pontuação e transforma o texto em minúsculas
        texto = texto.translate(str.maketrans('', '', string.punctuation)).lower()
        
        # Divide o texto em palavras
        palavras = texto.split()
        
        # Conta as palavras
        contagem = Counter(palavras)

        # Ordena do mais frequente para o menos frequente
        contagem_ordenada = dict(contagem.most_common())

        return contagem_ordenada
    
    except FileNotFoundError:
        print(f'Arquivo {nome_arquivo} não encontrado.')
        return {}

# Usar a função com o nome do arquivo
resultado = contar_palavras("estomago.txt")

# Mostrar as 20 palavras mais comuns
print("Palavras mais frequentes:")
for palavra, freq in list(resultado.items())[:20]:
    print(f"{palavra}: {freq}")
# Out:
# Palavras mais frequentes:
# de: 1274
# e: 962
# o: 889
# a: 750
# nonato: 668
# que: 661
# um: 477
# do: 404
# é: 348
# com: 330
# não: 297
# da: 292
# uma: 288
# no: 243
# na: 235
# em: 235
# se: 227
# para: 222
# : 211
# os: 188

# %% [markdown]
# ### Q3.
#
# Crie uma função chamada ```mesclar_dicionarios``` que recebe dois dicionários como parâmetros e retorna um novo dicionário contendo a fusão dos dois. Se houver chaves comuns, o maior valor deve prevalecer.

# %%
# Implemente aqui a função mesclar_dicionarios

def mesclar_dicionarios(d1, d2):
    # Criar uma cópia do primeiro dicionário para evitar modificá-lo diretamente
    resultado = d1.copy()
    
    # Atualizar o dicionário resultado com os elementos do segundo dicionário
    for chave, valor in d2.items():
        # Se a chave já existe no resultado, escolhe o maior valor
        if chave in resultado:
            resultado[chave] = max(resultado[chave], valor)
        else:
            resultado[chave] = valor
    
    return resultado

# Exemplo de uso
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}

resultado = mesclar_dicionarios(dicionario1, dicionario2)
print(resultado)
# Out:
# {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %%
# Exemplo de uso:
dicionario1 = {'a': 1, 'b': 2, 'c': 3}
dicionario2 = {'b': 4, 'd': 5}
resultado = mesclar_dicionarios(dicionario1, dicionario2)
print(resultado)
# Saída esperada: {'a': 1, 'b': 4, 'c': 3, 'd': 5}
# Out:
# {'a': 1, 'b': 4, 'c': 3, 'd': 5}

# %% [markdown]
# ### Q4.
#
# Desenvolva uma função em Python chamada ```filtrar_dicionario``` que recebe um dicionário e uma lista de chaves como parâmetros e retorna um novo dicionário contendo apenas as chaves que estão presentes na lista.

# %%
# Implemente aqui a função filtrar_dicionario
def filtrar_dicionario(dicionario, chaves):
    # Criar um novo dicionário apenas com as chaves que estão na lista
    return {chave: dicionario[chave] for chave in chaves if chave in dicionario}

# Exemplo de uso
dicionario = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
chaves = ['a', 'c', 'd']

resultado = filtrar_dicionario(dicionario, chaves)
print(resultado)
# Out:
# {'a': 1, 'c': 3, 'd': 4}

# %%
# Exemplo de uso:
dados = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
chaves_filtradas = ['a', 'c', 'e']
resultado = filtrar_dicionario(dados, chaves_filtradas)
print(resultado)
# Saída esperada: {'a': 1, 'c': 3, 'e': 5}
# Out:
# {'a': 1, 'c': 3, 'e': 5}

# %% [markdown]
# ### Q5.
#
# Você está responsável por analisar os resultados de uma votação. Cada voto é representado por um dicionário com o nome do candidato e a quantidade de votos que recebeu em uma determinada sessão eleitoral. Escreva uma função chamada ```resultado_votacao``` que recebe uma lista de dicionários de votos e retorna um dicionário onde as chaves são os nomes dos candidatos, e os valores são tuplas ```(total, percentual)``` com o total de votos recebidos por cada candidato e o percentual em relação à soma total de votos em todos os candidatos.

# %%
# Implemente aqui a função resultado_votacao

def resultado_votacao(votacoes):
    # Inicializamos um dicionário para armazenar o total de votos por candidato
    totais = {}

    # Contabiliza os votos totais de cada candidato
    for sessao in votacoes:
        for candidato, votos in sessao.items():
            if candidato in totais:
                totais[candidato] += votos
            else:
                totais[candidato] = votos

    # Soma total de votos em todas as sessões
    total_votos = sum(totais.values())

    # Calcula o percentual de votos de cada candidato
    resultados = {}
    for candidato, total in totais.items():
        percentual = (total / total_votos) * 100
        resultados[candidato] = (total, round(percentual, 2))

    return resultados

# Exemplo de uso
votacoes = [
    {'João': 150, 'Maria': 200, 'Pedro': 50},
    {'João': 100, 'Maria': 150, 'Ana': 100},
    {'João': 120, 'Pedro': 80, 'Maria': 100}
]

resultado = resultado_votacao(votacoes)
print(resultado)
# Out:
# {'João': (370, 35.24), 'Maria': (450, 42.86), 'Pedro': (130, 12.38), 'Ana': (100, 9.52)}

# %%
# Exemplo de uso:
votos = [
    {'candidato_A': 120, 'candidato_B': 85, 'candidato_C': 90},
    {'candidato_A': 110, 'candidato_B': 95, 'candidato_C': 80},
    {'candidato_A': 130, 'candidato_B': 78, 'candidato_C': 105},
]
resultado = resultado_votacao(votos)
print(resultado)  # Saída esperada: {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 
                                ###  'candidato_C': (275, 30.79)}
# Out:
# {'candidato_A': (360, 40.31), 'candidato_B': (258, 28.89), 'candidato_C': (275, 30.8)}
