# %% [markdown]
# # Set
#
# ## Aula 8.1

# %% [markdown]
# ### Q1.
#
# Dada uma string qualquer, use seu conhecimento de sets para apresentar os caracteres únicos que aparecem na string, ordenados alfabeticamente e sem duplicatas. Preste atenção em duplicatas de maiúsculas e minúsculas.

# %%
frase = "O rato roeu a roupa do Robson"

## Implemente aqui sua solução
def caracteres_unicos_ordenados(texto):
    # Passo 1: converter para letras minúsculas
    texto = texto.lower()
    
    # Passo 2: criar um conjunto (set) com caracteres únicos, ignorando espaços
    caracteres_unicos = {c for c in texto if c != ' '}
    
    # Passo 3: ordenar os caracteres
    caracteres_ordenados = sorted(caracteres_unicos)
    
    # Passo 4: retornar o resultado
    return caracteres_ordenados

# Entrada do usuário
entrada = input("Digite uma frase ou palavra: ")

# Processar
resultado = caracteres_unicos_ordenados(entrada)

# Exibir resultado
print("Caracteres únicos ordenados:")
print(resultado)
# Out:
# Digite uma frase ou palavra:  O rato roeu a roupa do Robson
# Caracteres únicos ordenados:
# ['a', 'b', 'd', 'e', 'n', 'o', 'p', 'r', 's', 't', 'u']

# %% [markdown]
# ### Q2
#
# Desenvolva uma função em Python chamada ```tem_elementos_comuns()``` que recebe duas listas como parâmetros e retorna True se houver algum elemento comum entre as duas listas, e False caso contrário. Utilize sets para resolver essa tarefa.

# %%
# Implemente aqui a função tem_elementos_comuns()
# Implemente aqui a função tem_elementos_comuns()
# Implemente aqui a função tem_elementos_comuns()
def tem_elementos_comuns(lista1, lista2):
    # Converte as listas em conjuntos
    conjunto1 = set(lista1)
    conjunto2 = set(lista2)

    # Verifica se existe algum elemento em comum
    return len(conjunto1 & conjunto2) > 0

# Teste
lista1 = [1, 2, 3, 4]
lista2 = [3, 4, 5, 6, 7]
resultado = tem_elementos_comuns(lista1, lista2)
print(resultado)  # Saída esperada: True
# Out:
# True

# %%
# Execute esta célula para testar a função da Q2.

lista1 = [1, 2, 3, 4]
lista2 = [3, 4, 5, 6, 7]
resultado = tem_elementos_comuns(lista1, lista2)
print(resultado)  # Saída esperada: True
# Out:
# True

# %% [markdown]
# ### Q3.
#
# Você vai coletar de diferentes turmas de alunos seus interesses em atividades extra curriculares dentre futebol, vôlei, rugby, música, teatro, ações comunitárias. Informe o conjunto de atividades comuns a todas a turmas. Pode preencher o iterável turmas com valores arbitrários.

# %%
turmas = [
     {'ações comunitárias', 'futebol', 'música', 'rugby'},
     {'ações comunitárias', 'música', 'rugby', 'teatro'},
     {'música', 'rugby', 'teatro', 'vôlei'},
     {'música', 'vôlei', 'rugby'},
     {'ações comunitárias', 'futebol', 'rugby', 'teatro', 'vôlei'},
     {'ações comunitárias', 'futebol', 'rugby'},
     {'ações comunitárias', 'rugby', 'teatro', 'vôlei'},
     {'ações comunitárias', 'rugby', 'teatro', 'vôlei'},
     {'ações comunitárias', 'rugby', 'vôlei'}
]


## Implemente aqui sua solução
turmas = [
    {'ações comunitárias', 'futebol', 'música', 'rugby'},
    {'ações comunitárias', 'música', 'rugby', 'teatro'},
    {'música', 'rugby', 'teatro', 'vôlei'},
    {'música', 'vôlei', 'rugby'},
    {'ações comunitárias', 'futebol', 'rugby', 'teatro', 'vôlei'},
    {'ações comunitárias', 'futebol', 'rugby'},
    {'ações comunitárias', 'rugby', 'teatro', 'vôlei'},
    {'ações comunitárias', 'rugby', 'teatro', 'vôlei'},
    {'ações comunitárias', 'rugby', 'vôlei'}
]

# Encontra as atividades comuns a todas as turmas
atividades_comuns = set.intersection(*turmas)

print("Atividades comuns a todas as turmas:", atividades_comuns)
# Out:
# Atividades comuns a todas as turmas: {'rugby'}

# %% [markdown]
# ### Q4.
# Considere duas listas que são duplicatas uma da outra, exceto por um elemento, exemplo:
# ```
# A = [1, 4, 5, 7, 9]
# B = [4, 5, 7, 9]
# ```
#
# Encontre e apresente o elemento diferente, informando também qual das listas está desfalcada. Para o exemplo acima, a saída esperada é
# ```
# O elemento 1 está faltando na segunda lista
# ```

# %%
## Implemente aqui sua solução

def encontrar_diferenca(A, B):
    set_A = set(A)
    set_B = set(B)
    
    # Verifica qual lista está com um elemento a menos
    if len(A) > len(B):
        diferenca = set_A - set_B
        lista_faltando = "segunda"
    else:
        diferenca = set_B - set_A
        lista_faltando = "primeira"
    
    if diferenca:
        elemento_faltando = diferenca.pop()
        print(f"O elemento {elemento_faltando} está faltando na {lista_faltando} lista")
    else:
        print("As listas são iguais ou não há apenas um elemento diferente")

# Exemplo
A = [1, 4, 5, 7, 9]
B = [4, 5, 7, 9]

encontrar_diferenca(A, B)
# Out:
# O elemento 1 está faltando na segunda lista

# %% [markdown]
# ### Q5.
#
# Panagramas são frases que contém todas as letras do alfabeto pelo menos uma vez. Crie uma função ```checa_panagrama``` que recebe uma string e retorna ```True``` caso seja um panagrama ou ```False```caso contrário. Use seu conhecimento de sets para solucionar essa questão.
#
# Ex:
# ```
# Entrada: "The quick brown fox jumps over the lazy dog"
# Saída: É um panagrama
# ```
#
# ```
# Entrada: "Python é uma linguagem de programação"
# Saída: Não é um panagrama
# ```

# %%
## Implemente aqui sua solução

def checa_panagrama(frase):
    # Define o alfabeto em letras minúsculas
    alfabeto = set('abcdefghijklmnopqrstuvwxyz')
    
    # Converte a frase para minúsculas e filtra apenas letras
    letras_frase = set(char.lower() for char in frase if char.isalpha())
    
    # Verifica se todas as letras do alfabeto estão presentes na frase
    if alfabeto.issubset(letras_frase):
        print("É um panagrama")
        return True
    else:
        print("Não é um panagrama")
        return False

# Exemplos de uso
checa_panagrama("The quick brown fox jumps over the lazy dog")  # É um panagrama
checa_panagrama("Python é uma linguagem de programação")        # Não é um panagrama
# Out:
# É um panagrama
# Não é um panagrama
# False
